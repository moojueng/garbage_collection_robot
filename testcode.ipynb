# %%
# YOLOv8 및 Roboflow 라이브러리 설치
# !pip install ultralytics roboflow

# 설치 확인 (GPU가 잡혔는지 확인)
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZRdO3IVNxqGjfdqX4qzP")
project = rf.workspace("ecosift-h6jkl").project("can-iewc4")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to can-1 in yolov8:: 100%|██████████| 3368/3368 [00:00<00:00, 6742.02it/s]

# %%
from ultralytics import YOLO

# 1. 모델 불러오기 (yolov8s.pt 추천)
model = YOLO('yolov8s.pt')

# 2. 학습 시작
# data: 다운로드한 데이터셋 경로 (Roboflow 코드가 dataset 변수에 경로를 저장해줍니다)
# epochs: 1600장이면 50~80번만 돌려도 충분할 수 있지만, 안전하게 100번 설정 (조기 종료 기능이 있어 과적합 시 알아서 멈춥니다)
# imgsz: 데이터셋이 640x640으로 리사이즈 되어 있으므로 640 설정
model.train(
    data=f'{dataset.location}/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    name='can_detection_model' # 결과 저장 폴더 이름
)
# Out:
# ...
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
